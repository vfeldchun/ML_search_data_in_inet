# %% [markdown]
# ## Домашнее задание к Уроку 4

# %% [markdown]
# ### Задание:

# %% [markdown]
# 1. Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, которая будет добавлять только новые вакансии/продукты в вашу базу.
# 2. Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы (необходимо анализировать оба поля зарплаты).

# %% [markdown]
# ### Решение:

# %% [markdown]
# #### Импортируем необходимые библиотеки

# %%
import requests
from fake_useragent import UserAgent
from copy import deepcopy
from time import sleep
from pprint import pprint
import json
from pymongo import MongoClient
from pymongo.errors import DuplicateKeyError

# %% [markdown]
# #### Определяем необходимые переменные

# %%
# Зададим переменную поиска
KEY_SEARCH_STRING = 'Python'

# Зададим типовую структуру вакансии для наполнения списка вакансий
tmp_vacancy_dict = {
    # Наименование вакансии
    'vacancy': '',
    # Зарплата включая минимум, максимум и валюту
    'salary': {'min_salary': 0., 'max_salary': 0., 'currency': ''},
    # Ссылка на описание вакансии
    'vacancy_link': '',
    # источник вакансии
    'vacancy_source': 'hh.ru',
    # Наименование работодателя
    'name_of_employer': '',
    # Место работы (город или удаленка)
    'city_of_work': '',
    # условия работы - полный день, удаленка
    'type_of_work': ''
}

# %% [markdown]
# #### Определим необходимые функции

# %%
def get_headhunter_vacancies(headhunter_url, headhunter_request_params, npages):
    # С данного сайта получить данные вакансий можно через api в json формате
    # Инициализируем список словарей для хранения вакансий
    headhunter_vacancy_list = []

    # Организуем цикл сбора информации
    for i in range(npages):
        # Чтобы избежать ошибки о превышении количества запросов
        sleep(2)

        # Заносим в параметры запроса номер страницы
        headhunter_request_params['page'] = str(i)

        # Выполним запрос к сайту, ответ преобразуем в json а затем в список
        headhunter_respond = requests.get(url=headhunter_url, params=headhunter_request_params)
        headhunter_respond_json_list = (headhunter_respond.json())['items']

        if headhunter_respond.ok:
            # Для каждой вакансии
            for one_vacancy in headhunter_respond_json_list:
                # Заполняем словарь вакансии
                tmp_vacancy_dict['vacancy'] = one_vacancy['name']

                if one_vacancy['salary'] is None:
                    tmp_vacancy_dict['salary']['min_salary'] = 0.0
                    tmp_vacancy_dict['salary']['max_salary'] = 0.0
                    tmp_vacancy_dict['salary']['currency'] = ''
                else:
                    if one_vacancy['salary']['from'] is None:
                        tmp_vacancy_dict['salary']['min_salary'] = 0.0
                    else:
                        tmp_vacancy_dict['salary']['min_salary'] = float(one_vacancy['salary']['from'])

                    if one_vacancy['salary']['to'] is None:
                        tmp_vacancy_dict['salary']['max_salary'] = 0.0
                    else:
                        tmp_vacancy_dict['salary']['max_salary'] = float(one_vacancy['salary']['to'])

                    tmp_vacancy_dict['salary']['currency'] = one_vacancy['salary']['currency']

                tmp_vacancy_dict['vacancy_link'] = one_vacancy['alternate_url']
                tmp_vacancy_dict['name_of_employer'] = one_vacancy['employer']['name']
                tmp_vacancy_dict['city_of_work'] = one_vacancy['area']['name']
                tmp_vacancy_dict['type_of_work'] = one_vacancy['schedule']['name']

                # Добавляем вакансю в список вакансий
                headhunter_vacancy_list.append(deepcopy(tmp_vacancy_dict))
        else:
            break

    return headhunter_vacancy_list

# %%
def find_new_vacancy_and_insert_to_db(new_vacancy_list, vacancy_collection):
    
    # Выгрузим из БД имеющиеся вакансии без поля _id
    headhunter_db_vacancy_list = list(vacancy_collection.find({'vacancy': {'$exists': True}}, {'_id': False}))

    # Создадим пустой список вакансий для вставки в БД
    headhunter_diff_list_to_insertion = []

    # Для каждого словаря из полученного после парсинга списка
    for item in new_vacancy_list:
        # Проверим есть ли вакансия в БД
        if item not in headhunter_db_vacancy_list:
            # Если нет, добавим словарь в список для вставки
            headhunter_diff_list_to_insertion.append(item)

    # Если были обнаружены новые ваканчии то
    if len(headhunter_diff_list_to_insertion) > 0:
        # Внесем полученный список вакансий в БД
        x = headhunter_collection.insert_many(headhunter_diff_list_to_insertion)
        vacancy_count = len(headhunter_diff_list_to_insertion)
        return vacancy_count
    else:
        return 0

# %% [markdown]
# #### Основное тело программы

# %%
# Задаем url для запроса
headhunter_url = 'https://api.hh.ru/vacancies'

# Зададим словарь параметров для запросов на сайте HeadHunter
headhunter_request_params = {
    'text': KEY_SEARCH_STRING,
    'area': '1',
    'items_on_page': '20',
    'page': '0'
}

# %% [markdown]
# #### Подключимся и создадим структуру БД в MangoDB

# %%
#Подключимся к локальной MongoDB
local_mdb_client = MongoClient('mongodb://localhost:27017/')
# Подключимся к БД vacancy_db
vacancy_db = local_mdb_client['vacancy_db']
# Подключим коллекцию headhunter
headhunter_collection = vacancy_db['headhunter']

# %% [markdown]
# #### Обработка новых вакансий разработчика python для города Москвы с сайта HeadHunter

# %%
# %%time
# Инициализируем список вакансий
headhunter_vacancy_list = []
# Инициализируем маркер ошибки
hh_err = False

# Получим список вакансий hh
try:
    headhunter_vacancy_list = get_headhunter_vacancies(headhunter_url, headhunter_request_params, npages=40)
except Exception as e:
    # печатаем ошибку
    err_msg = f'При обработке вакансий на headhunter.ru произошла ошибка: {e}'
    print(err_msg)
    hh_err = True

if not hh_err:
    # Запишем в базу MangoDB vacancy_db словари с вакансиями hh
    # Что бы избежать дубликатов вакансий запись в базу, проверим что в БД нет таких вакансий
    
    new_vacancy_update_number = find_new_vacancy_and_insert_to_db(headhunter_vacancy_list, headhunter_collection)
    
    if new_vacancy_update_number > 0:
        print(f'В БД vacancy_db было добавлено {new_vacancy_update_number} новых вакансий!')
        print(f'Всего вакансий в БД vacancy_db.headhunter {len(list(headhunter_collection.find({})))}')
    else:
        print(f'На сайте headhunter.ru не появилось новых вакансий!')

    # Очищаем все списки данных
    #headhunter_vacancy_list.clear()
    #headhunter_diff_list_to_insertion.clear()
# Out:
# В БД vacancy_db было добавлено 20 новых вакансий!
# Всего вакансий в БД vacancy_db.headhunter 820
# Wall time: 1min 36s

# %%
# Проверим количество вакансий в БД на данный момент
len(list(headhunter_collection.find()))
# Out:
# 820

# %% [markdown]
# #### Поиск и вывод на экран вакансии с заработной платой больше введённой суммы

# %%
# Зададим функция поиска и вывода вакансий из БД по параметру величины зарплаты
# По умолчанию будут выводиться зарплаты больше указанного размера зарплаты (volume_of_salary).
# При изменнении is_gt на False будут найдены вакансии меньше указаного обьема зарплаты
def print_vacancy_by_salary_number(vacancy_collection, volume_of_salary, is_gt = True):
    
    # Определим кретерий поиска: больше или меньше указаного обьма зарплаты
    if is_gt:
        operator = '$gt'
        operator_symbol = '>'
    else:
        operator = '$lt'
        operator_symbol = '<'
    
    # Зададим стороку поиска
    vacancy_query_dict = {
        "salary.min_salary": {operator: volume_of_salary}, 
        "salary.max_salary": {operator: volume_of_salary}
    }
    
    # Выполним поиск вакансий по заданным кретериям
    vacancy_with_requested_salary_cursor = vacancy_collection.find(vacancy_query_dict)
    
    finded_vacancy_count = len(list(vacancy_collection.find(vacancy_query_dict)))
    
    print(f'Количество найденных вакансий с размером зарплаты {operator_symbol} {volume_of_salary}: {finded_vacancy_count}')
    print('Список найденных вакансий:\n')
    for item in vacancy_with_requested_salary_cursor:
        pprint(item)

# %%
print_vacancy_by_salary_number(headhunter_collection, 100000)
# Out:
# Количество найденных вакансий с размером зарплаты > 100000: 55
# Список найденных вакансий:
#
# {'_id': ObjectId('63f8d278121c6a068244e791'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Нетопия',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77091465',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e792'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Дубайт',
#  'salary': {'currency': 'RUR', 'max_salary': 500000.0, 'min_salary': 300000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик C# / Python',
#  'vacancy_link': 'https://hh.ru/vacancy/71147348',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e793'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Перфект Системс',
#  'salary': {'currency': 'RUR', 'max_salary': 450000.0, 'min_salary': 300000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python Backend Developer / WEB - разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/72216524',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7a5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': '7RedLines',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 160000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/76925483',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7a8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Юрент',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 160000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Аналитик данных / Data Analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/77334669',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ab'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Астор',
#  'salary': {'currency': 'RUR', 'max_salary': 240000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/74376536',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ac'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'АНО Инфокультура',
#  'salary': {'currency': 'RUR', 'max_salary': 180000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик бэкэнд (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76712573',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'HR Prime',
#  'salary': {'currency': 'RUR', 'max_salary': 280000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/77015802',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b7'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Enjoypro',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 160000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/71069892',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b9'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Мамаева Ирина Анатольевна',
#  'salary': {'currency': 'RUR', 'max_salary': 350000.0, 'min_salary': 250000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist middle+/Senior',
#  'vacancy_link': 'https://hh.ru/vacancy/77208642',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7bf'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'DIGINETICA',
#  'salary': {'currency': 'RUR', 'max_salary': 240000.0, 'min_salary': 170000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data Scientist (Middle+)',
#  'vacancy_link': 'https://hh.ru/vacancy/76810036',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7d1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Смарт Текнолоджис,ООО',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 120000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Программист Python (Middle, Senior)',
#  'vacancy_link': 'https://hh.ru/vacancy/76413549',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7d3'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Russian Quantum Center',
#  'salary': {'currency': 'RUR', 'max_salary': 450000.0, 'min_salary': 250000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Fullstack Python техлид (Облачные квантовые вычисления)',
#  'vacancy_link': 'https://hh.ru/vacancy/76924335',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7d5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Группа компаний МЕДСИ',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 180000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python разработчик (удалённо)',
#  'vacancy_link': 'https://hh.ru/vacancy/75955276',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7d6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'НАО Финансовые системы',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/74257661',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7dc'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'AERODISK',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 140000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/75679088',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7de'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'РВИ',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/75921771',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e9'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Платформа Больших Данных',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 250000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data-engeneer (Middle)',
#  'vacancy_link': 'https://hh.ru/vacancy/76921562',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7f0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лаборатория Маркетинга',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle Python Backend Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76588590',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7fb'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Контент лайн',
#  'salary': {'currency': 'RUR', 'max_salary': 170000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Backend-разработчик (Python, Django)',
#  'vacancy_link': 'https://hh.ru/vacancy/77096613',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7fd'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Альфа Базис',
#  'salary': {'currency': 'RUR', 'max_salary': 240000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Ведущий Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77155591',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e807'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ФЛАУВАУ',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 140000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'WEB/Data-аналитик',
#  'vacancy_link': 'https://hh.ru/vacancy/76412397',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e80b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Селфсек',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle Python developer',
#  'vacancy_link': 'https://hh.ru/vacancy/72687504',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e811'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Whoosh (ООО Вуш)',
#  'salary': {'currency': 'RUR', 'max_salary': 350000.0, 'min_salary': 250000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/68492110',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e814'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'РЕСТАДВАЙЗЕР',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle / Middle+ Python Developer (backend)',
#  'vacancy_link': 'https://hh.ru/vacancy/77073241',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e81d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'modesco',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Backend Python developer (senior/middle+)',
#  'vacancy_link': 'https://hh.ru/vacancy/76827509',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e82e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Эдшот',
#  'salary': {'currency': 'RUR', 'max_salary': 350000.0, 'min_salary': 250000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Ведущий full-stack разработчик (Python, JS)',
#  'vacancy_link': 'https://hh.ru/vacancy/76941049',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e839'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Reputation House',
#  'salary': {'currency': 'RUR', 'max_salary': 350000.0, 'min_salary': 300000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Senior Python+Go developer',
#  'vacancy_link': 'https://hh.ru/vacancy/77223951',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e83d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'AlfaBit.Group',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик Python / Django (Middle)',
#  'vacancy_link': 'https://hh.ru/vacancy/77061996',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e83f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Нектар',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик Perl',
#  'vacancy_link': 'https://hh.ru/vacancy/77156084',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e841'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': 'RUR', 'max_salary': 400000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python разработчик (Intelligent Document Processing)',
#  'vacancy_link': 'https://hh.ru/vacancy/77016383',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e882'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Баззула Интернет Технологии',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Инженер инфраструктуры / DevOps / SRE',
#  'vacancy_link': 'https://hh.ru/vacancy/76688347',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e887'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'МШП',
#  'salary': {'currency': 'RUR', 'max_salary': 240000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle DevOps-инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/76549029',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8b1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'PA Profrecrut (ИП Камовская Ирина Вячеславовна)',
#  'salary': {'currency': 'RUR', 'max_salary': 150000.0, 'min_salary': 120000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных (SQL)',
#  'vacancy_link': 'https://hh.ru/vacancy/76785567',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8b6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Центр инженерной физики МГУ',
#  'salary': {'currency': 'RUR', 'max_salary': 140000.0, 'min_salary': 110000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик программного обеспечения (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76842261',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8b8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ВижнЛабс (VisionLabs)',
#  'salary': {'currency': 'RUR', 'max_salary': 280000.0, 'min_salary': 225000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76287050',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8bc'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': 'RUR', 'max_salary': 400000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python-разработчик в Цифровые поверхности Салют '
#             '(направление B2B2C)',
#  'vacancy_link': 'https://hh.ru/vacancy/77016351',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8c0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'БК Олимп',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Backend разработчик (Python/Go)',
#  'vacancy_link': 'https://hh.ru/vacancy/71136278',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8cd'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Галлямов Раиль Нафисович',
#  'salary': {'currency': 'RUR', 'max_salary': 350000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Senior Python developer (FastApi + Django)',
#  'vacancy_link': 'https://hh.ru/vacancy/77034438',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8d1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'HR Prime',
#  'salary': {'currency': 'RUR', 'max_salary': 290000.0, 'min_salary': 170000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python / BE Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76711288',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8d5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Точных Приборов, НИИ',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 120000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/76718141',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8f5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СмартРейс',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Backend Developer (Python) Middle+ / Team Lead',
#  'vacancy_link': 'https://hh.ru/vacancy/76889492',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e8f6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Шпак Виктория Сергеевна',
#  'salary': {'currency': 'RUR', 'max_salary': 350000.0, 'min_salary': 280000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Ведущий разработчик (Python+JavaScript)',
#  'vacancy_link': 'https://hh.ru/vacancy/75682198',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e905'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'CyberPhysics',
#  'salary': {'currency': 'RUR', 'max_salary': 180000.0, 'min_salary': 160000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/76446137',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e93e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Ярус',
#  'salary': {'currency': 'RUR', 'max_salary': 350000.0, 'min_salary': 150000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'DevOps engineer/Системный администратор',
#  'vacancy_link': 'https://hh.ru/vacancy/76847262',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e94e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'DSS Lab (ДСС Лаб)',
#  'salary': {'currency': 'RUR', 'max_salary': 200000.0, 'min_salary': 160000.0},
#  'type_of_work': 'Гибкий график',
#  'vacancy': 'DevOps-инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/77014718',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e96f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Flipper Devices',
#  'salary': {'currency': 'RUR', 'max_salary': 220000.0, 'min_salary': 140000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle Python Developer (Backend / Server side)',
#  'vacancy_link': 'https://hh.ru/vacancy/77148120',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e977'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СиРеЭм Сенсор',
#  'salary': {'currency': 'RUR', 'max_salary': 150000.0, 'min_salary': 130000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'DevOps-инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/77210228',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e97a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Пэйлер',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'DevOps (FinTech) || Remote',
#  'vacancy_link': 'https://hh.ru/vacancy/72881401',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e97b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'O.dev',
#  'salary': {'currency': 'RUR', 'max_salary': 170000.0, 'min_salary': 140000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Big-Data инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/77339875',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e980'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'МФТИ ГУ',
#  'salary': {'currency': 'RUR', 'max_salary': 210000.0, 'min_salary': 170000.0},
#  'type_of_work': 'Гибкий график',
#  'vacancy': 'ML-Researcher (NLP)',
#  'vacancy_link': 'https://hh.ru/vacancy/76471092',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e98b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'МФК ВЭББАНКИР',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 120000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data scientist / Аналитик риск-моделей',
#  'vacancy_link': 'https://hh.ru/vacancy/77181469',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea41'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'HR Prime',
#  'salary': {'currency': 'RUR', 'max_salary': 270000.0, 'min_salary': 230000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Продуктовый аналитик',
#  'vacancy_link': 'https://hh.ru/vacancy/76659794',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea62'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Поток.Диджитал',
#  'salary': {'currency': 'RUR', 'max_salary': 300000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data scientist (remote)',
#  'vacancy_link': 'https://hh.ru/vacancy/76417738',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea93'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ОТП Банк, АО (OTP bank)',
#  'salary': {'currency': 'RUR', 'max_salary': 250000.0, 'min_salary': 200000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle Data Scientist (Big Data)',
#  'vacancy_link': 'https://hh.ru/vacancy/73088535',
#  'vacancy_source': 'hh.ru'}

# %%
print_vacancy_by_salary_number(headhunter_collection, 100000, False)
# Out:
# Количество найденных вакансий с размером зарплаты < 100000: 639
# Список найденных вакансий:
#
# {'_id': ObjectId('63f8d278121c6a068244e795'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Завистовская Анжелика Сергеевна',
#  'salary': {'currency': 'RUR', 'max_salary': 80000.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Junior Python Backend Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/77372405',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e796'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Apostro',
#  'salary': {'currency': 'USD', 'max_salary': 8000.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Ведущий Python разработчик (удаленка)',
#  'vacancy_link': 'https://hh.ru/vacancy/76832091',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e798'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Welltory',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python Developer по работе с ChatGPT (генеративным AI)',
#  'vacancy_link': 'https://hh.ru/vacancy/77144612',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e799'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'АйТи Интеллект',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python developer',
#  'vacancy_link': 'https://hh.ru/vacancy/77302829',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e79c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'NOVA',
#  'salary': {'currency': 'RUR', 'max_salary': 80000.0, 'min_salary': 45000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Web-программист Python+Django (удаленно)',
#  'vacancy_link': 'https://hh.ru/vacancy/77241702',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e79e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'WILDBERRIES',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77324208',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7a2'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Samsung Research Russia',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Developer (Backend)',
#  'vacancy_link': 'https://hh.ru/vacancy/77294601',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7a6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ГКУ Инфогород',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76160225',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ad'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Первый Бит',
#  'salary': {'currency': 'RUR', 'max_salary': 70000.0, 'min_salary': 50000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Начинающий программист BI (sql/python/js)',
#  'vacancy_link': 'https://hh.ru/vacancy/76569529',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ВАТСОН',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python Developer (Remote)',
#  'vacancy_link': 'https://hh.ru/vacancy/77278703',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python (Сбербанк Страхование)',
#  'vacancy_link': 'https://hh.ru/vacancy/77343039',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b2'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Эйч-Эль-Эль',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Программист Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77218092',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b3'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'LATOKEN',
#  'salary': {'currency': 'USD', 'max_salary': 0.0, 'min_salary': 1000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python developer (remote)',
#  'vacancy_link': 'https://hh.ru/vacancy/77244580',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Константа',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python developer',
#  'vacancy_link': 'https://hh.ru/vacancy/75574711',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7b8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лига Цифровой Экономики',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Data Engineer (junior)',
#  'vacancy_link': 'https://hh.ru/vacancy/76141435',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ba'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'SberTech',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77197403',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7bc'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'билайн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77279686',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7be'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'НТехЛаб',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python developer (проекты)',
#  'vacancy_link': 'https://hh.ru/vacancy/69533479',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7c0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Novakid Inc',
#  'salary': {'currency': 'USD', 'max_salary': 4000.0, 'min_salary': 3000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data Analyst (Remote)',
#  'vacancy_link': 'https://hh.ru/vacancy/74736547',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7c1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Московская Биржа',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Junior QA Automation (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76275217',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7c3'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ORO',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Менеджер по обработке данных (SPSS, SAS, Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76290598',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7c4'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Филиал компании Лист Ренталс Лимитед',
#  'salary': {'currency': 'USD', 'max_salary': 4000.0, 'min_salary': 2000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle Python Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76820856',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7c5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Teachbase',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76544211',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7c8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Девман',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Ментор на курс Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77259417',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7c9'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик (SmartVoice)',
#  'vacancy_link': 'https://hh.ru/vacancy/76294359',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ca'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ОМТ-Консалт, Группа компаний',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Backend Developer Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77365703',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7cb'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Банк СОЮЗ (АО)',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик - разработчик (SQL+Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/77000852',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ce'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Константа',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python developer (FastApi)',
#  'vacancy_link': 'https://hh.ru/vacancy/76911595',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7d0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Яндекс',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python-разработчик во внутренний каталог сервисов',
#  'vacancy_link': 'https://hh.ru/vacancy/77085769',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7d4'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Ритм',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик на python в команду новых сервисов',
#  'vacancy_link': 'https://hh.ru/vacancy/75770861',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7da'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python / Go Разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/74089202',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Яндекс',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик бэкенда на Python в Вертикали',
#  'vacancy_link': 'https://hh.ru/vacancy/76831391',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Lesta Games',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Developer (Infrastructure)',
#  'vacancy_link': 'https://hh.ru/vacancy/76680884',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e2'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лаборатория Касперского',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python developer (KATA)',
#  'vacancy_link': 'https://hh.ru/vacancy/77298455',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e3'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'РАСЧЕТНЫЕ РЕШЕНИЯ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/53864420',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e4'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных / Data Analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/69166398',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Группа компаний Астра',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python (ALD)',
#  'vacancy_link': 'https://hh.ru/vacancy/70052938',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Банк Хоум Кредит',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Junior Data аналитик (Департамент противодействия мошенничеству)',
#  'vacancy_link': 'https://hh.ru/vacancy/76272398',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7e8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ЭкспрессДеньги',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76321282',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ea'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Профессиональный экологический консалтинг',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных (Data Analist)',
#  'vacancy_link': 'https://hh.ru/vacancy/76584671',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ed'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лаборатория Касперского',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python developer (NTA)',
#  'vacancy_link': 'https://hh.ru/vacancy/77298598',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ee'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ИТ-Экспертиза',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных (Data Scientist) / ML-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77223284',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ef'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'УК Академия Будущего',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Аналитик/Эксперт для проведения практических уроков по Excel, '
#             'SQL, Python (удаленно)',
#  'vacancy_link': 'https://hh.ru/vacancy/76782468',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7f2'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Adwile',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python - разработчик (Middle), удаленно',
#  'vacancy_link': 'https://hh.ru/vacancy/76112984',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7f3'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Т8',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Backend Developer (Django)',
#  'vacancy_link': 'https://hh.ru/vacancy/77088738',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7f6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': '3LOGIC GROUP',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77090228',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7f7'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Яндекс',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python Developer (Беспилотные автомобили)',
#  'vacancy_link': 'https://hh.ru/vacancy/76985818',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7f8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Rubetek',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77075044',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7fa'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Scalaxi',
#  'salary': {'currency': 'RUR', 'max_salary': 0.0, 'min_salary': 60000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Low-code (создание и внедрение приложений в рамках платформы)',
#  'vacancy_link': 'https://hh.ru/vacancy/77035768',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7fc'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Team4You',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Программист Python/С++',
#  'vacancy_link': 'https://hh.ru/vacancy/77208048',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7fe'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'CLS Global',
#  'salary': {'currency': 'USD', 'max_salary': 6000.0, 'min_salary': 5000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76650700',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e7ff'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Красное & Белое, розничная сеть',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Программист-разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/69900189',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e800'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'AdCombo.com',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python backend разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77073026',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e801'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Щербин Алексей Сергеевич',
#  'salary': {'currency': 'RUR', 'max_salary': 60000.0, 'min_salary': 40000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python-разработчик (Junior)',
#  'vacancy_link': 'https://hh.ru/vacancy/76729452',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e802'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Eiwa (ООО Рекламная платформа)',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Deep Learning инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/76752873',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e803'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Работут',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных',
#  'vacancy_link': 'https://hh.ru/vacancy/77219984',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e804'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лента, федеральная розничная сеть',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/77075807',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e805'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СберМаркет',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Junior + Data Engineer в СберМаркет',
#  'vacancy_link': 'https://hh.ru/vacancy/77122368',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e806'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'NGENIX',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик Python (Middle, Senior)',
#  'vacancy_link': 'https://hh.ru/vacancy/55088580',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e808'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'VK',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python-разработчик (команда WorkSpace)',
#  'vacancy_link': 'https://hh.ru/vacancy/77091209',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e809'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'IBS',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Инженер по автоматизации тестирования Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77332335',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e80a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ВСК, САО',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик OCR/ML/NER (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76220566',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e80c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Верме',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle BackEnd разработчик (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76445416',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e80e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'АНО ЦИСМ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76868566',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e80f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Дартс рекрутинг сервисез',
#  'salary': {'currency': 'USD', 'max_salary': 0.0, 'min_salary': 6500.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Team Lead Python',
#  'vacancy_link': 'https://hh.ru/vacancy/69431362',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e815'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Junior/Middle ML Researcher в Sber AI Lab',
#  'vacancy_link': 'https://hh.ru/vacancy/77282409',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e816'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лаборатория Наносемантика',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76780632',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e817'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Caltat',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Backend python (стажер)',
#  'vacancy_link': 'https://hh.ru/vacancy/76223564',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e818'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'AliExpress Россия',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Engineer / Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77017983',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e819'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Сулак Капитал',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python developer (middle/senior) удаленно',
#  'vacancy_link': 'https://hh.ru/vacancy/77321723',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e81a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'билайн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Аналитик данных',
#  'vacancy_link': 'https://hh.ru/vacancy/76920748',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e81b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'BAUM STORAGE',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Software Developer (AI)',
#  'vacancy_link': 'https://hh.ru/vacancy/76806633',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e81c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'АВИТО ТЕХ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик в команду Market Intelligence',
#  'vacancy_link': 'https://hh.ru/vacancy/77076479',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e81e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Северсталь',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик (проект Лаборатория измерительных систем)',
#  'vacancy_link': 'https://hh.ru/vacancy/77193986',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e81f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'НОВОСИСТЕМ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python developer (middle)',
#  'vacancy_link': 'https://hh.ru/vacancy/76105043',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e820'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных / Data Analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/76869170',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e822'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'look.online',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик',
#  'vacancy_link': 'https://hh.ru/vacancy/77287472',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e823'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Ростелеком',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77147240',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e824'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Novakid Inc',
#  'salary': {'currency': 'USD', 'max_salary': 5000.0, 'min_salary': 4000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Team Lead with back-end (Python) - remote',
#  'vacancy_link': 'https://hh.ru/vacancy/77363153',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e825'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'БСТ Менеджмент-Консалтинг',
#  'salary': {'currency': 'RUR', 'max_salary': 0.0, 'min_salary': 40000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Эконометрист/Data scientist (Junior/Middle) в консалтинг',
#  'vacancy_link': 'https://hh.ru/vacancy/75546364',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e826'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Gear Games',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Гибкий график',
#  'vacancy': 'QA Engineer на мобильную RTS',
#  'vacancy_link': 'https://hh.ru/vacancy/73576354',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e827'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Спортмастер',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Junior Data scientist (RecSys)',
#  'vacancy_link': 'https://hh.ru/vacancy/76975464',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e829'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'билайн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data-analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/76417646',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e82a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ИТЕРАНЕТ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle backend-разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/76140465',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e82c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'BI.ZONE',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77032460',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e82d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python-разработчик (команда SberWorks)',
#  'vacancy_link': 'https://hh.ru/vacancy/77133306',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e82f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Stellar Labs',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist / ML Инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/76827021',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e830'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Нетология',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python-разработчик в ML',
#  'vacancy_link': 'https://hh.ru/vacancy/76717976',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e831'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Hexlet',
#  'salary': {'currency': 'RUR', 'max_salary': 80000.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python программист (Наставник онлайн-курса по Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/67864415',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e832'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Инфотек',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle backend developer (Python), remote',
#  'vacancy_link': 'https://hh.ru/vacancy/74063789',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e833'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ФККГруп',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Программист qlikview',
#  'vacancy_link': 'https://hh.ru/vacancy/77285800',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e834'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лаборатория Касперского',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'SDET Python (Network Traffic Analyzer)',
#  'vacancy_link': 'https://hh.ru/vacancy/77241066',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e835'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'билайн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist (LTV)',
#  'vacancy_link': 'https://hh.ru/vacancy/76536709',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e838'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77052276',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e83c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Красное & Белое, розничная сеть',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Программист-разработчик компьютерного зрения (python)',
#  'vacancy_link': 'https://hh.ru/vacancy/77002334',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e83e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Gear Games',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Game Analyst (игровой аналитик)',
#  'vacancy_link': 'https://hh.ru/vacancy/76254367',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e840'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Sape',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных / Data Analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/76987868',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e844'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'IQnergy',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data analyst / Аналитик данных',
#  'vacancy_link': 'https://hh.ru/vacancy/73591237',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e846'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Ресурсный центр Департамента здравоохранения города '
#                      'Москвы',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/76973737',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e847'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Диалог Регионы',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Junior Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76805135',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e848'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ПроКомплаенс',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python (middle)',
#  'vacancy_link': 'https://hh.ru/vacancy/76816845',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e849'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Айтигенио',
#  'salary': {'currency': 'USD', 'max_salary': 800.0, 'min_salary': 300.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Преподаватель по программированию в онлайн-школе (Python в '
#             'Minecraft)',
#  'vacancy_link': 'https://hh.ru/vacancy/76843216',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e84a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Skyeng',
#  'salary': {'currency': 'RUR', 'max_salary': 80000.0, 'min_salary': 40000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Наставник курсов по Python разработке',
#  'vacancy_link': 'https://hh.ru/vacancy/77332277',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e84b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': '2ГИС',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python backend-разработчик в команду Data Science',
#  'vacancy_link': 'https://hh.ru/vacancy/77050354',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e84d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'РДП.РУ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/76980532',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e84e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ЭкспрессДеньги',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик корпоративных массивов данных (с навыками в Data '
#             'Science, Machine Learning)',
#  'vacancy_link': 'https://hh.ru/vacancy/76385297',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e850'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Группа Самолет',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Старший Python Developer (Django), проекты в строительной сфере',
#  'vacancy_link': 'https://hh.ru/vacancy/76905717',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e852'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Домклик',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/68077706',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e856'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ЧУ ДО Московская школа программистов',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Team Lead',
#  'vacancy_link': 'https://hh.ru/vacancy/76707495',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e857'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Sitronics Group',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python (Middle)',
#  'vacancy_link': 'https://hh.ru/vacancy/73852842',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e858'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Телеканал Россия, ГТК',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Гибкий график',
#  'vacancy': 'Аналитик данных / Data Analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/77068297',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e859'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лента, федеральная розничная сеть',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'TechLead (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/72234221',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e85b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'LOGISTIX',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик баз данных (PostgreSQL)',
#  'vacancy_link': 'https://hh.ru/vacancy/77228239',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e85c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лента, федеральная розничная сеть',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior/Middle Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/74351176',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e85d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'OKKAM',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle\xa0Python Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76521668',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e85f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle Python developer (команда SberWorks)',
#  'vacancy_link': 'https://hh.ru/vacancy/77232242',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e860'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'билайн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик базы данных',
#  'vacancy_link': 'https://hh.ru/vacancy/75522993',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e861'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'URSiP',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/75914254',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e862'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ИнфоТеКС',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Ведущий разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/72398896',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e863'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Сулак Капитал',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Teamlead Python developer, удаленно',
#  'vacancy_link': 'https://hh.ru/vacancy/77321451',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e864'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76971042',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e867'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Skyeng',
#  'salary': {'currency': 'RUR', 'max_salary': 50000.0, 'min_salary': 30000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Ментор (лектор) курса по Python-разработке',
#  'vacancy_link': 'https://hh.ru/vacancy/76540298',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e868'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Junior/Middle Data Scientist SberData',
#  'vacancy_link': 'https://hh.ru/vacancy/76911900',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e869'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'билайн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data-аналитик',
#  'vacancy_link': 'https://hh.ru/vacancy/76933775',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e86a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Платформа Сейлз Чейн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle+/Senior Backend Developer (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76910287',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e86b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ГРЧЦ, ФГУП',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python midlle',
#  'vacancy_link': 'https://hh.ru/vacancy/77060955',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e86c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Райтек',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'FPGA DSP разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76971851',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e86d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'НТ Прогресс',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Fullstack developer Python-JS / Фулстек-Разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/72731847',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e86f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Skyeng',
#  'salary': {'currency': 'RUR', 'max_salary': 80000.0, 'min_salary': 40000.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Наставник курсов по Python разработке',
#  'vacancy_link': 'https://hh.ru/vacancy/76767074',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e870'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Иннотех, Группа компаний',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Старший разработчик python',
#  'vacancy_link': 'https://hh.ru/vacancy/77263772',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e873'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Опен Вижн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/76934078',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e874'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Франчайзинговая розничная сеть Галамарт',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Team Lead Python backend (удаленно)',
#  'vacancy_link': 'https://hh.ru/vacancy/76445564',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e876'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Hexlet',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Автор курсов по Python',
#  'vacancy_link': 'https://hh.ru/vacancy/72748475',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e877'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'билайн',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик Python (Senior)',
#  'vacancy_link': 'https://hh.ru/vacancy/73383410',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e879'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'EGAR TECHNOLOGY, INC.',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/76030657',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e87a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Комита Цифровые Технологии',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/75883895',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e87b'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Яндекс',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Аналитик-разработчик в качество Геопоиска',
#  'vacancy_link': 'https://hh.ru/vacancy/76204659',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e87c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ИЦ АЙ-ТЕКО',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77021851',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e87d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Ай-Теко (I-Teco)',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Главный разработчик Python',
#  'vacancy_link': 'https://hh.ru/vacancy/77234497',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e87f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Группа компаний «Group4Media», Управляющая компания',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Fullstack Python Developer / Python Разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76399952',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e880'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Python (ETL)',
#  'vacancy_link': 'https://hh.ru/vacancy/77077906',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244e881'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Ростелеком',
# ...
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior OpenStack Python specialist',
#  'vacancy_link': 'https://hh.ru/vacancy/75725924',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea91'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'START.RU',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Аналитик данных',
#  'vacancy_link': 'https://hh.ru/vacancy/71393741',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea92'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'QIWI',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Разработчик SQL/Аналитик',
#  'vacancy_link': 'https://hh.ru/vacancy/75968513',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea94'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Engineer в команду «Сеть Продаж»',
#  'vacancy_link': 'https://hh.ru/vacancy/70417491',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea95'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Bell Integrator',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Аналитик данных',
#  'vacancy_link': 'https://hh.ru/vacancy/76415529',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea96'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'INFOWATCH',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python developer (ARMA)',
#  'vacancy_link': 'https://hh.ru/vacancy/75916375',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea97'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Emerging Travel Group (Ostrovok.ru, B2B.Ostrovok, '
#                      'RateHawk, ZenHotels)',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Senior Python Developer (Cashbox)',
#  'vacancy_link': 'https://hh.ru/vacancy/76560756',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea98'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'IBS',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'QA Auto инженер (Python + Selenium)',
#  'vacancy_link': 'https://hh.ru/vacancy/76732373',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea99'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'CV Engineer (SberDevices)',
#  'vacancy_link': 'https://hh.ru/vacancy/73080486',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea9a'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'WILDBERRIES',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик Go, Анализ текста (DS/NLP)',
#  'vacancy_link': 'https://hh.ru/vacancy/75886390',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea9c'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'МТС',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Python Middle developer департамент Интеграции (MTS AI)',
#  'vacancy_link': 'https://hh.ru/vacancy/75847797',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea9d'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СИНЕРГИЯ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'ML-engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/55441562',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea9e'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'HR Prime',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Продуктовый аналитик',
#  'vacancy_link': 'https://hh.ru/vacancy/76821725',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244ea9f'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Samsung Research Russia',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior ML Research Engineer (Smart Watch)',
#  'vacancy_link': 'https://hh.ru/vacancy/68800655',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Спортмастер',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Data scientist (RecSys)',
#  'vacancy_link': 'https://hh.ru/vacancy/75981474',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'VK',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist (Рекламные технологии)',
#  'vacancy_link': 'https://hh.ru/vacancy/76453041',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa2'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'КРОК',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python-разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/76420469',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa3'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'МойОфис',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior Python developer',
#  'vacancy_link': 'https://hh.ru/vacancy/76417817',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa4'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'МТС',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Senior Backend Python Developer (MTS AI)',
#  'vacancy_link': 'https://hh.ru/vacancy/76088932',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Micare Tech',
#  'salary': {'currency': 'USD', 'max_salary': 5000.0, 'min_salary': 3000.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Разработчик С++',
#  'vacancy_link': 'https://hh.ru/vacancy/76340269',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'VK',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data scientist / разработчик-исследователь (NLP)',
#  'vacancy_link': 'https://hh.ru/vacancy/76400850',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'the_covert',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Гибкий график',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/75573623',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaa9'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist (Рекомендательные системы)',
#  'vacancy_link': 'https://hh.ru/vacancy/68115103',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaaa'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Лаборатория Касперского',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Software Development Engineer in Test (SDET) [Python, Linux]',
#  'vacancy_link': 'https://hh.ru/vacancy/76488544',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaab'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'МТС',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Middle+/Senior Python developer на продукт ONEtools (Big Data)',
#  'vacancy_link': 'https://hh.ru/vacancy/76649923',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaac'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ФосАгро',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist ( Аналитик данных )',
#  'vacancy_link': 'https://hh.ru/vacancy/76537733',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaad'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'MERLION',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Гибкий график',
#  'vacancy': 'Аналитик - Разработчик Data Science',
#  'vacancy_link': 'https://hh.ru/vacancy/74059409',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaae'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'T4MP',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Team Lead Python Developer (location anywhere)',
#  'vacancy_link': 'https://hh.ru/vacancy/76305176',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63f8d278121c6a068244eaaf'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'NLP - Разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/69986728',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19b4'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'MindSet',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Удаленный стажер-аналитик (графовые базы данных)',
#  'vacancy_link': 'https://hh.ru/vacancy/77347089',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19b5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Hoodies',
#  'salary': {'currency': 'USD', 'max_salary': 5000.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Senior Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/77381420',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19b6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Группа Самолет',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/72888902',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19b7'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'СБЕР',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Python Team lead (CloudHalo)',
#  'vacancy_link': 'https://hh.ru/vacancy/72784234',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19b8'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ГК ВИЗАВИ Консалт',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle Data Scientist / ML Engineer (Time series)',
#  'vacancy_link': 'https://hh.ru/vacancy/76628486',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19b9'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Сервионика',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Администратор Linux/разработчик Ansible',
#  'vacancy_link': 'https://hh.ru/vacancy/76399381',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19ba'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Спортмастер',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle Data / ML Engineer (Автокоммуникации)',
#  'vacancy_link': 'https://hh.ru/vacancy/76775596',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19bb'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Go Ahead',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'ML инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/74088632',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19bc'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Бэнкс Софт Системс',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'DevOps / Релиз-инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/76756920',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19bd'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Okko',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Senior ML Engineer ("Поиск")',
#  'vacancy_link': 'https://hh.ru/vacancy/75789492',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19be'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Lexicom',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Системный администратор Linux / Инженер внедрения',
#  'vacancy_link': 'https://hh.ru/vacancy/76382807',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19bf'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Spice Agency',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Senior backend developer (Python+Go)',
#  'vacancy_link': 'https://hh.ru/vacancy/76090621',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19c0'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'QIWI',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data инженер',
#  'vacancy_link': 'https://hh.ru/vacancy/76133437',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19c1'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'РДП.РУ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'QA Automation Engineer (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/76541305',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19c2'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'Гринатом',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Middle+/Senior Python Developer Центр HR TECH (Проект Цифровой '
#             'Ассистент)',
#  'vacancy_link': 'https://hh.ru/vacancy/76450681',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19c3'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'HR Prime',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Product Analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/76679101',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19c4'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ФИНАМ',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Удаленная работа',
#  'vacancy': 'Lead QA (Python)',
#  'vacancy_link': 'https://hh.ru/vacancy/75665602',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19c5'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'VK',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/76778233',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63fa1401a4ac5f5598fe19c6'),
#  'city_of_work': 'Москва',
#  'name_of_employer': 'ГАУ Города Москвы Центр цифровизации образования',
#  'salary': {'currency': '', 'max_salary': 0.0, 'min_salary': 0.0},
#  'type_of_work': 'Полный день',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/76461371',
#  'vacancy_source': 'hh.ru'}
